# %%
import pandas as pd
import matplotlib as plt
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
import scikitplot as skplt #displays confusion matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# %%
data = pd.read_csv('tweetsLabels (1).csv')

# %%
data
# Out:
#     index                                               Text  Likes  Type  \
# 0       0  جبت لكم خبر مُذهل رائع وجمييييل ايهيرب مسويين ...      0     1
# 1       1  جدةالأن ايهيرب مسوين خصومات جبااارة حتى 60 لحق...      0     1
# 2       2  زودتهايافاجر ايهيرب مسوين خصومات جبااارة حتى 6...      1     1
# 3       3  مقاطعهفلاورد ايهيرب مسوين خصومات جداااا جميلة ...      0     1
# 4       4          اذا بدت خصومات ايهيرب علموني احب الخصومات      0     1
# ..    ...                                                ...    ...   ...
# 74     75  غسول الجسم الأفريقي أفضل صابون ينظف وينعم وريح...      2     3
# 75     76  كريم للتخلص من خطوط التمدد ،يحتاج الاستمرارية ...      1     3
# 76     77  مرطبات الشفايف ترطب وتنعم حيل وروائحها منعشة و...      0     3
# 77     78  ڤيتامين C مكمل غذائي مناسب للبالغين والأطفال ف...      0     3
# 78     79                     اوميقا ثري بيفرق معاك بالتساقط      0     3
#
#     Label
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# ...

# %%
feature_cols =['Likes','Type']

# %%
X = data[feature_cols] # Features

# %%
y = data.Label # Target variable

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=1) 
# 70% training and 30% test

# %%
clf = DecisionTreeClassifier() #get an instance of the classifier

# %%
clf = clf.fit(X_train,y_train) #training

# %%
y_pred = clf.predict(X_test) #make predictions

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8333333333333334

# %%
skplt.metrics.plot_confusion_matrix(y_test, y_pred, normalize=True, title = 'Confusion Matrix for iHerb')
# Out:
# <AxesSubplot:title={'center':'Confusion Matrix for iHerb'}, xlabel='Predicted label', ylabel='True label'>

# %%
print('Precision: %.3f' % precision_score(y_test, y_pred))
# Out:
# Precision: 0.947

# %%
	
print('Recall: %.3f' % recall_score(y_test, y_pred))
# Out:
# Recall: 0.857

# %%
print('Accuracy: %.3f' % accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.833

# %%
print('F1 score:', f1_score(y_test, y_pred, average='binary'))
# Out:
# F1 score: 0.9

# %%
# %config InlineBackend.figure_format = 'svg' # to increase the resolution of the image

_ = tree.plot_tree(clf, #our classifier
                   feature_names=feature_cols,  
                   class_names='01',
                   filled=True)

# %%
text_representation = tree.export_text(clf)
print(text_representation)
# Out:
# |--- feature_1 <= 2.50
# |   |--- feature_1 <= 1.50
# |   |   |--- feature_0 <= 0.50
# |   |   |   |--- class: 1
# |   |   |--- feature_0 >  0.50
# |   |   |   |--- class: 1
# |   |--- feature_1 >  1.50
# |   |   |--- feature_0 <= 6.50
# |   |   |   |--- feature_0 <= 0.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- feature_0 >  0.50
# |   |   |   |   |--- feature_0 <= 1.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_0 >  1.50
# |   |   |   |   |   |--- class: 1
# |   |   |--- feature_0 >  6.50
# |   |   |   |--- class: 0
# |--- feature_1 >  2.50
# |   |--- feature_0 <= 0.50
# |   |   |--- feature_1 <= 3.50
# |   |   |   |--- class: 1
# |   |   |--- feature_1 >  3.50
# |   |   |   |--- class: 1
# |   |--- feature_0 >  0.50
# |   |   |--- class: 1

# %%
import numpy
type(y_test) #numpy.ndarray
y_test=numpy.asarray(y_test) #after splitting into 70% training and 30% test, y_test returned as multi-dimentional
                               #array, aka "numpy.ndarray", so we want to convert to normal array to manipulate easily



for i in range(24): # iterte throughout the actual labels, and the resultant ones and comparing them
    print('predicted: ',y_pred[i] ,'actual: ',y_test[i])
# Out:
# predicted:  1 actual:  1
# predicted:  1 actual:  1
# predicted:  1 actual:  1
# predicted:  1 actual:  1
# predicted:  1 actual:  1
# predicted:  1 actual:  1
# predicted:  1 actual:  1
# predicted:  1 actual:  1
# predicted:  1 actual:  1
# predicted:  1 actual:  1
# predicted:  1 actual:  0
# predicted:  0 actual:  1
# predicted:  1 actual:  1
# predicted:  1 actual:  1
# predicted:  1 actual:  1
# predicted:  1 actual:  1
# predicted:  0 actual:  1
# predicted:  0 actual:  0
# predicted:  1 actual:  1
# predicted:  0 actual:  1
# predicted:  1 actual:  1
# predicted:  1 actual:  1
# predicted:  0 actual:  0
# predicted:  1 actual:  1
